# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd/content/drive/MyDrive/commit_git
# Out:
# /content/drive/MyDrive/commit_git

# %%
# !git clone https://yeonjun-git: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@github.com/yeonjun-git/visual.git
# Out:
# Cloning into 'visual'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), 1.74 KiB | 13.00 KiB/s, done.

# %%
cd visual
# Out:
# /content/drive/MyDrive/commit_git/visual

# %%
# !git config --global user.email 'lyj09029@gmail.com'
# !git config --global user.name 'yeonjun-git'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd/content/drive/MyDrive/commit_git/visual
# Out:
# /content/drive/MyDrive/commit_git/visual

# %%
# !git add --all visual
# Out:
# fatal: pathspec 'visual' did not match any files
